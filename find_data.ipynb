# %%
import pandas as pd
import pymongo

# %%
uri = "mongodb+srv://LOLcluster:1234@cluster0.iiixibs.mongodb.net/?retryWrites=true&w=majority"
client = pymongo.MongoClient(uri)
db = client.LOLdata
lolCollection = db.LOL_records

# %%
data = list(lolCollection.find())
serpApi= data[0]["serpApi"]
lol_pantip = data[1]["lol_pantip"]
reddit_api = data[2]["reddit_api"]

print(serpApi.keys())
data = {'twitter list':serpApi["twitter_list"]}
df = pd.DataFrame(data)
df

# print(lol_pantip)
# data = {'Reddit ':reddit_api}
# df = pd.DataFrame(data)
# df
# Out:
# dict_keys(['ads_list', 'twitter_list', 'topStories_list', 'question_list', 'searchResults_list', 'searchFor'])
#                                          twitter list
# 0   Wow,my postdoc advisor, a white woman from Mai...
# 1   In Mexico and only on mobile, was watching the...
# 2   GUYS! seems like i can head home today 🥲 ive b...
# 3   Join us today on our gaming PC's 6-11 pm to gr...
# 4                    1st LoL game and I'm confused AF
# 5   “The Album” is the Jonas Brothers 7TH album an...
# 6   Lol i cant get a lyft so i guess i'm walking b...
# 7   So apart from the obvious lol who else is seei...
# 8   The "Let's go Boston!" chant got me thinking I...
# 9   Lol. So will @seattlestorm have any players th...
# 10  Was our match against Sociedad a fever dream? ...
# 11  anyone else have the most insane dreams after ...
# 12  i saw first hand though why great players are ...
# 13                                  y’all ready ? Lol
# 14  the way the warriors are managing the vets thi...
# 15  What if LeBron breaks the scoring record again...
# 16  ⚒️ Patch Notes 4.0a ⚒️ 🔥Base Burning 🪨Inhibito...
# 17  Dive into a new adventure with this week's fre...
# 18  Here's a "First Look" at the balance changes f...
# 19  Here's this week's free-to-play rotation! Let ...
# 20  There's always something new to try on the Rif...
